# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
#I'm working on a csv file that has data collected by State and local health departments between April 1995 to 2015
#The data depicts the number of children below six years, the states surveyed by CDC and the different Blood lead levels
 
import pandas as pd
import numpy as np

BLL= pd.read_csv('childhood-lead.csv')
print(BLL)
print('/n')
# Out:
#      Year        State  Population  < 72 months old  # of Children Tested  \
# 0    1997      Alabama                     357087.0               22875.0
# 1    1998      Alabama                     352409.0               17827.0
# 2    1999      Alabama                     349592.0               17660.0
# 3    2000      Alabama                     356676.0               13719.0
# 4    2001      Alabama                     357111.0               12107.0
# ..    ...          ...                          ...                   ...
# 793  2011  U.S. Totals                   24452138.0             4070635.0
# 794  2012  U.S. Totals                   24324502.0             2938161.0
# 795  2013  U.S. Totals                   24209230.0             2418668.0
# 796  2014  U.S. Totals                   24205138.0             2675145.0
# 797  2015  U.S. Totals                   24219632.0             2415604.0
#
#      Total  #  of Children with Confirmed BLL ≥10 µg/dL  \
# ...

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
#unique values in each column

print(BLL.nunique())
# Out:
# Year                                                   20
# State                                                  44
# Population  < 72 months old                           595
# # of Children Tested                                  592
# Total  #  of Children with Confirmed BLL ≥10 µg/dL    487
# % of Children Tested with Confirmed BLLs ≥10 µg/dL    594
# 5-9 µg/dL                                             183
# ≥5 µg/dL                                              182
# 10-14 µg/dL                                           449
# 15-19 µg/dL                                           336
# 20-24 µg/dL                                           243
# 25-44 µg/dL                                           249
# 45-69 µg/dL                                            94
# ≥70 µg/dL                                              42
# dtype: int64

# %%
BLL=BLL.drop_duplicates(subset= ['% of Children Tested with Confirmed BLLs ≥10 µg/dL'])
BLL
# Out:
#      Year        State  Population  < 72 months old  # of Children Tested  \
# 0    1997      Alabama                     357087.0               22875.0
# 1    1998      Alabama                     352409.0               17827.0
# 2    1999      Alabama                     349592.0               17660.0
# 3    2000      Alabama                     356676.0               13719.0
# 4    2001      Alabama                     357111.0               12107.0
# ..    ...          ...                          ...                   ...
# 793  2011  U.S. Totals                   24452138.0             4070635.0
# 794  2012  U.S. Totals                   24324502.0             2938161.0
# 795  2013  U.S. Totals                   24209230.0             2418668.0
# 796  2014  U.S. Totals                   24205138.0             2675145.0
# 797  2015  U.S. Totals                   24219632.0             2415604.0
#
#      Total  #  of Children with Confirmed BLL ≥10 µg/dL  \
# ...

# %%
BLL['% of Children Tested with Confirmed BLLs ≥10 µg/dL'].unique()
# Out:
# array([0.0656    , 0.0554    , 0.0311    , 0.023     , 0.053     ,
#        0.0236    , 0.0288    , 0.0137    , 0.01079441, 0.00738443,
#        0.00620309, 0.0105    , 0.0071    , 0.00532462, 0.00739284,
#        0.00401065, 0.00520321, 0.00463345,        nan, 0.0871    ,
#        0.025     , 0.0212    , 0.3248    , 0.0377    , 0.0061    ,
#        0.00395273, 0.00240533, 0.00250226, 0.0023    , 0.00126822,
#        0.00164327, 0.00129118, 0.00132453, 0.00194343, 0.1833    ,
#        0.1566    , 0.1541    , 0.1161    , 0.0932    , 0.011     ,
#        0.01085829, 0.00397636, 0.00266499, 0.00218052, 0.00205529,
#        0.00204458, 0.0025    , 0.0082    , 0.0355    , 0.0301    ,
#        0.0267    , 0.017     , 0.0126    , 0.00169133, 0.0133    ,
#        0.0397    , 0.0328    , 0.0367    , 0.03      , 0.0229    ,
#        0.0218    , 0.0189    , 0.01660744, 0.01473022, 0.0144636 ,
#        0.00917763, 0.00952809, 0.00927958, 0.00715121, 0.01803864,
# ...

# %%
BLL['% of Children Tested with Confirmed BLLs ≥10 µg/dL'].value_counts()
# Out:
# 0.002506    1
# 0.031900    1
# 0.001808    1
# 0.009300    1
# 0.006933    1
#            ..
# 0.001933    1
# 0.013447    1
# 0.002665    1
# 0.097700    1
# 0.007232    1
# Name: % of Children Tested with Confirmed BLLs ≥10 µg/dL, Length: 594, dtype: int64

# %%
BLL=BLL.drop_duplicates(subset= ['Population  < 72 months old'])
BLL
# Out:
#      Year        State  Population  < 72 months old  # of Children Tested  \
# 0    1997      Alabama                     357087.0               22875.0
# 1    1998      Alabama                     352409.0               17827.0
# 2    1999      Alabama                     349592.0               17660.0
# 3    2000      Alabama                     356676.0               13719.0
# 4    2001      Alabama                     357111.0               12107.0
# ..    ...          ...                          ...                   ...
# 793  2011  U.S. Totals                   24452138.0             4070635.0
# 794  2012  U.S. Totals                   24324502.0             2938161.0
# 795  2013  U.S. Totals                   24209230.0             2418668.0
# 796  2014  U.S. Totals                   24205138.0             2675145.0
# 797  2015  U.S. Totals                   24219632.0             2415604.0
#
#      Total  #  of Children with Confirmed BLL ≥10 µg/dL  \
# ...

# %%
BLL['Population  < 72 months old'].unique()
# Out:
# array([  357087.,   352409.,   349592.,   356676.,   357111.,   355715.,
#          357382.,   360396.,   365075.,   370240.,   374378.,   377117.,
#          365443.,   363869.,   360597.,   356565.,   355222.,   354230.,
#          437505.,   462341.,   459141.,   463085.,   506655.,   526883.,
#          553123.,   587953.,   605565.,   616345.,   619403.,   534113.,
#          527769.,   522392.,   521060.,   521310.,  3204502.,  3104123.,
#         3029049.,  3018386.,  3034623.,  3159667.,  3191914.,  3209321.,
#         3252643.,  3284693.,  3036508.,  3037143.,  3014451.,  3017125.,
#          331728.,   339604.,   345246.,   359123.,   370914.,   405720.,
#          260336.,   261163.,   263845.,   270187.,   270763.,   261945.,
#          260760.,   257471.,   257952.,   256698.,   255423.,   253975.,
#          245428.,   241912.,   237873.,   233754.,   231071.,   228774.,
#           59811.,    59695.,    60211.,    62122.,    62380.,    64227.,
# ...

# %%
BLL['Population  < 72 months old'].value_counts()
# Out:
# 463357.0    1
# 383774.0    1
# 73945.0     1
# 48854.0     1
# 278663.0    1
#            ..
# 62122.0     1
# 889585.0    1
# 774814.0    1
# 167079.0    1
# 870401.0    1
# Name: Population  < 72 months old, Length: 595, dtype: int64

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
#There seems to be no row which has the same value in my data set except groups of few where the same state repeats

BLL.groupby("State").count()
# Out:
#                       Year  Population  < 72 months old  # of Children Tested  \
# State
# Alabama                 18                           18                    18
# Arizona                 16                           16                    15
# California              12                           12                    12
# Colorado                 6                            6                     6
# Connecticut             18                           18                    18
# Delaware                18                           18                    18
# District of Columbia    12                           12                    12
# Florida                 15                           15                    15
# Georgia                 15                           15                    15
# Houston only             1                            1                     1
# Illinois                17                           17                    17
# ...

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
import pandas as pd
import numpy as np

# %%
BLL= pd.read_csv('childhood-lead.csv')

# %%
len(BLL)
# Out:
# 798

# %%
BLL['Total  #  of Children with Confirmed BLL ≥10 µg/dL'].hist(figsize=(11,5.5))

# %%
BLL['Year'].hist(bins=20,figsize=(11,5.5))

# %%
BLL[['# of Children Tested', 'Total  #  of Children with Confirmed BLL ≥10 µg/dL']].hist(figsize=(11,5.5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6379cc69e8>,
# ...
#       dtype=object)

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
BLL.plot.scatter(x='Year', y='Total  #  of Children with Confirmed BLL ≥10 µg/dL', color='Orange', label='Blood lead level in children between 1997 and 2015',figsize=(13,7))

# %%
BLL.plot(x='State',y=['Population  < 72 months old','# of Children Tested','Total  #  of Children with Confirmed BLL ≥10 µg/dL','% of Children Tested with Confirmed BLLs ≥10 µg/dL'],figsize=(20,11))

# %%
BLL= BLL[BLL['State'].isin(['Alabama','Arizona','Conneticut','California', 'Colorado'])]
by_state= BLL.groupby('State')

# %%
BLL
# Out:
#     Year     State  Population  < 72 months old  # of Children Tested  \
# 0   1997   Alabama                     357087.0               22875.0
# 1   1998   Alabama                     352409.0               17827.0
# 2   1999   Alabama                     349592.0               17660.0
# 3   2000   Alabama                     356676.0               13719.0
# 4   2001   Alabama                     357111.0               12107.0
# ..   ...       ...                          ...                   ...
# 71  2011  Colorado                     411855.0                   NaN
# 72  2012  Colorado                     408722.0                   NaN
# 73  2013  Colorado                     405810.0                   NaN
# 74  2014  Colorado                     405720.0               16555.0
# 75  2015  Colorado                     406769.0                   NaN
#
#     Total  #  of Children with Confirmed BLL ≥10 µg/dL  \
# 0                                              1501.0
# ...

# %%
import seaborn as sns

# %%
sns.barplot(x='State',y='% of Children Tested with Confirmed BLLs ≥10 µg/dL', data= BLL)

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# Submit your work as usual.
